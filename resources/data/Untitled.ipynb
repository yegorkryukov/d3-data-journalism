# %%
import pandas as pd

# %%
df = pd.read_csv('ACS_14_1YR_S2406_with_ann.csv')
df.head()
# Out:
#         GEO.id GEO.id2 GEO.display-label  \
# 0           Id     Id2         Geography
# 1  0400000US01      01           Alabama
# 2  0400000US02      02            Alaska
# 3  0400000US04      04           Arizona
# 4  0400000US05      05          Arkansas
#
#                                        HC01_EST_VC01  \
# 0  Total; Estimate; Civilian employed population ...
# 1                                            2030482
# 2                                             352531
# 3                                            2866629
# 4                                            1269092
#
#                                        HC01_MOE_VC01  \
# 0  Total; Margin of Error; Civilian employed popu...
# 1                                              13376
# 2                                               5376
# 3                                              19029
# 4                                              12369
#
#                                        HC02_EST_VC01  \
# ...

# %%
df.columns
# Out:
# Index(['GEO.id', 'GEO.id2', 'GEO.display-label', 'HC01_EST_VC01',
#        'HC01_MOE_VC01', 'HC02_EST_VC01', 'HC02_MOE_VC01', 'HC03_EST_VC01',
#        'HC03_MOE_VC01', 'HC04_EST_VC01', 'HC04_MOE_VC01', 'HC05_EST_VC01',
#        'HC05_MOE_VC01', 'HC06_EST_VC01', 'HC06_MOE_VC01', 'HC01_EST_VC02',
#        'HC01_MOE_VC02', 'HC02_EST_VC02', 'HC02_MOE_VC02', 'HC03_EST_VC02',
#        'HC03_MOE_VC02', 'HC04_EST_VC02', 'HC04_MOE_VC02', 'HC05_EST_VC02',
#        'HC05_MOE_VC02', 'HC06_EST_VC02', 'HC06_MOE_VC02', 'HC01_EST_VC03',
#        'HC01_MOE_VC03', 'HC02_EST_VC03', 'HC02_MOE_VC03', 'HC03_EST_VC03',
#        'HC03_MOE_VC03', 'HC04_EST_VC03', 'HC04_MOE_VC03', 'HC05_EST_VC03',
#        'HC05_MOE_VC03', 'HC06_EST_VC03', 'HC06_MOE_VC03', 'HC01_EST_VC04',
#        'HC01_MOE_VC04', 'HC02_EST_VC04', 'HC02_MOE_VC04', 'HC03_EST_VC04',
#        'HC03_MOE_VC04', 'HC04_EST_VC04', 'HC04_MOE_VC04', 'HC05_EST_VC04',
#        'HC05_MOE_VC04', 'HC06_EST_VC04', 'HC06_MOE_VC04', 'HC01_EST_VC05',
# ...

# %%
cols = [c for c in df.columns if c.lower()[5:8] != 'moe']
cols
# Out:
# ['GEO.id',
#  'GEO.id2',
#  'GEO.display-label',
#  'HC01_EST_VC01',
#  'HC02_EST_VC01',
#  'HC03_EST_VC01',
#  'HC04_EST_VC01',
#  'HC05_EST_VC01',
#  'HC06_EST_VC01',
#  'HC01_EST_VC02',
#  'HC02_EST_VC02',
#  'HC03_EST_VC02',
#  'HC04_EST_VC02',
#  'HC05_EST_VC02',
#  'HC06_EST_VC02',
#  'HC01_EST_VC03',
#  'HC02_EST_VC03',
#  'HC03_EST_VC03',
#  'HC04_EST_VC03',
#  'HC05_EST_VC03',
#  'HC06_EST_VC03',
#  'HC01_EST_VC04',
#  'HC02_EST_VC04',
#  'HC03_EST_VC04',
#  'HC04_EST_VC04',
#  'HC05_EST_VC04',
#  'HC06_EST_VC04',
#  'HC01_EST_VC05',
#  'HC02_EST_VC05',
#  'HC03_EST_VC05',
#  'HC04_EST_VC05',
#  'HC05_EST_VC05',
#  'HC06_EST_VC05',
#  'HC01_EST_VC06',
#  'HC02_EST_VC06',
#  'HC03_EST_VC06',
#  'HC04_EST_VC06',
#  'HC05_EST_VC06',
#  'HC06_EST_VC06',
#  'HC01_EST_VC09',
#  'HC02_EST_VC09',
#  'HC03_EST_VC09',
#  'HC04_EST_VC09',
#  'HC05_EST_VC09',
#  'HC06_EST_VC09']

# %%
df = df[cols]

# %%
df.head(1).T.to_csv('columns.csv')

# %%
df.describe()
# Out:
#              GEO.id GEO.id2 GEO.display-label HC01_EST_VC01 HC02_EST_VC01  \
# count            53      53                53            53            53
# unique           53      53                53            53            43
# top     0400000US23      48        California       1269092          70.0
# freq              1       1                 1             1             3
#
#        HC03_EST_VC01 HC04_EST_VC01 HC05_EST_VC01 HC06_EST_VC01 HC01_EST_VC02  \
# count             53            53            53            53            53
# unique            24            42            45            36            53
# top              3.4           7.8          12.0           5.7       1733574
# freq               7             3             4             4             1
#
#             ...      HC03_EST_VC06 HC04_EST_VC06 HC05_EST_VC06 HC06_EST_VC06  \
# count       ...                 53            53            53            53
# ...

# %%
df.to_csv('filtered.csv')

# %%
cols = ['GEO.display-label','HC01_EST_VC01','HC01_EST_VC02','HC01_EST_VC03','HC01_EST_VC04','HC01_EST_VC05','HC01_EST_VC06']

# %%
df[cols].to_csv('totals.csv')
